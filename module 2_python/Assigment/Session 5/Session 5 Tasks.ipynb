# %%
# 1 

playlist_ids = [101, 205, 309, 412, 578]
print("Playlist IDs:", playlist_ids)
# Out:
# Playlist IDs: [101, 205, 309, 412, 578]

# %%
# 2

playlist_ids = [101, 205, 309, 412, 578]
playlist_ids.append(650)
playlist_ids.extend([721, 845])

print("Updated Playlist IDs:", playlist_ids)
# Out:
# Updated Playlist IDs: [101, 205, 309, 412, 578, 650, 721, 845]

# %%
# 3

playlist_ids = [101, 205, 309, 412, 578, 650, 721, 845]
removed_song = playlist_ids.pop()

print("Removed Song ID:", removed_song)
print("Remaining Playlist:", playlist_ids)
# Out:
# Removed Song ID: 845
# Remaining Playlist: [101, 205, 309, 412, 578, 650, 721]

# %%
# 4

def remove_last_item(order_list):
    a = order_list.pop()
    print(order_list)
    return a

lst4 = [101, 102, 103, 104, 105]
b = remove_last_item(lst4)
print(b)
# Out:
# [101, 102, 103, 104]
# 105

# %%
# 5
zomato_orders = ["Pizza", "Burger", "Pasta"]


ipl_teams = (
    "CSK",
    "MI",
    "RCB",
    "KKR",
    "GT",
    "RR",
    "PBKS",
    "DC",
    "LSG",
    "SRH"
)


print("Zomato Orders (List):", zomato_orders)
print("IPL Teams (Tuple):", ipl_teams)
# Out:
# Zomato Orders (List): ['Pizza', 'Burger', 'Pasta']
# IPL Teams (Tuple): ('CSK', 'MI', 'RCB', 'KKR', 'GT', 'RR', 'PBKS', 'DC', 'LSG', 'SRH')
