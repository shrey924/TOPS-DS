# %%
# 1

insta_followers = {
    "viratkohli": 275000000,
    "priyankachopra": 93000000,
    "shraddhakapoor": 95000000,
    "aliaabhatt": 87000000,
    "deepikapadukone": 81000000
}

# Print the dictionary
print("Instagram Followers:", insta_followers)
# Out:
# Instagram Followers: {'viratkohli': 275000000, 'priyankachopra': 93000000, 'shraddhakapoor': 95000000, 'aliaabhatt': 87000000, 'deepikapadukone': 81000000}

# %%
# 2
# Create a dictionary of Instagram influencers and their follower counts
insta_followers = {
    "viratkohli": 275000000,
    "priyankachopra": 93000000,
    "shraddhakapoor": 95000000,
    "aliaabhatt": 87000000,
    "deepikapadukone": 81000000
}

# Add a new influencer
insta_followers["narendramodi"] = 110000000

# Update the follower count of an existing influencer
insta_followers["aliaabhatt"] = 88000000

# Delete one influencer
del insta_followers["deepikapadukone"]

# Print the updated dictionary
print("Updated Instagram Followers:", insta_followers)
# Out:
# Updated Instagram Followers: {'viratkohli': 275000000, 'priyankachopra': 93000000, 'shraddhakapoor': 95000000, 'aliaabhatt': 88000000, 'narendramodi': 110000000}

# %%
# 3

food_prices = {
    "Pizza": 299,
    "Burger": 149,
    "Biryani": 249,
    "Pasta": 199,
    "Paneer Tikka": 350
}
print("Food items costing more than ₹200:")
for item, price in food_prices.items():
    if price > 200:
        print(f"{item}: ₹{price}")
# Out:
# Food items costing more than ₹200:
# Pizza: ₹299
# Biryani: ₹249
# Paneer Tikka: ₹350

# %%
# 4

flipkart_users = {"rahul123", "priya456", "amit789", "neha101", "rohit202"}
myntra_users = {"priya456", "rohit202", "sneha303", "vikas404", "amit789"}
common_users = flipkart_users.intersection(myntra_users)


print("Users with accounts on both Flipkart and Myntra:")
print(common_users)
# Out:
# Users with accounts on both Flipkart and Myntra:
# {'amit789', 'priya456', 'rohit202'}

# %%
# 5

def get_unique_artists(spotify_playlist1, spotify_playlist2):
    return spotify_playlist1.union(spotify_playlist2)
    
spotify_playlist1 = {"Arijit Singh", "Shreya Ghoshal", "Diljit Dosanjh"}
spotify_playlist2 = {"Arijit Singh", "A. R. Rahman", "Neha Kakkar"}
unique_artists = get_unique_artists(spotify_playlist1, spotify_playlist2)
print("Unique Artists:", unique_artists)
# Out:
# Unique Artists: {'Shreya Ghoshal', 'Neha Kakkar', 'Diljit Dosanjh', 'A. R. Rahman', 'Arijit Singh'}
