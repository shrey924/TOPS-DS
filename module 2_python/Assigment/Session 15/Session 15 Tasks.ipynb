# %%
# 1 

def get_song_duration_per_minute(total_duration, number_of_songs):
    try:
        average_duration = total_duration / number_of_songs
        print("Average Duration per Song:", average_duration, "minutes")
    except ZeroDivisionError:
        print("Error: Number of songs cannot be zero.")
    finally:
        print("Calculation completed.")

get_song_duration_per_minute(60, 12)
print()
get_song_duration_per_minute(60, 0)
# Out:
# Average Duration per Song: 5.0 minutes
# Calculation completed.
#
# Error: Number of songs cannot be zero.
# Calculation completed.

# %%
# 2

try:
    total_amount = float(input("Enter total cart amount (₹): "))
    item_count = int(input("Enter number of items: "))
    price_per_item = total_amount / item_count

    print(f"Price per item: ₹{price_per_item:.2f}")
except ZeroDivisionError:
    print("Error: Your cart cannot have 0 items. Please enter a valid item count.")

except ValueError:
    print("Error: Please enter valid numeric values.")

finally:
    print("Thank you for using the Flipkart Price Calculator!")
# Out:
# Price per item: ₹50.00
# Thank you for using the Flipkart Price Calculator!

# %%
# 3

class NoOffersApplied(Exception):
    pass
try:
    total_spend = float(input("Enter total spend (₹): "))
    offers = int(input("Enter number of offers applied: "))
    if offers == 0:
        raise NoOffersApplied("No offers were applied. Cashback cannot be calculated.")

    average_cashback = total_spend / offers

    print(f"Average Cashback per Offer: ₹{average_cashback:.2f}")
except NoOffersApplied as e:
    print("Custom Error:", e)
except ValueError:
    print("Error: Please enter valid numeric values.")
finally:
    print("Thank you for using the Paytm Cashback Calculator!")
# Out:
# Average Cashback per Offer: ₹500.00
# Thank you for using the Paytm Cashback Calculator!

# %%
# 4
def calculate_average_rating(total_rating, num_reviews):
    try:
        return total_rating / num_reviews
    except ZeroDivisionError:
        print("Error: Number of reviews cannot be zero.")
        return None
    finally:
        print("Thank you for using the calculator")
result = calculate_average_rating(500, 0)
if result is not None:
    print("Average Rating:", result)
# Out:
# Error: Number of reviews cannot be zero.
# Thank you for using the calculator

# %%
# 5
def safe_divide_for_zomato(bill_amount, number_of_people):
    try:
        result = bill_amount / number_of_people
    except ZeroDivisionError:
        print("Error: Number of people cannot be zero.")
    else:
        print(f"Each person should pay: ₹{result:.2f}")
    finally:
        print("Split calculation done")
safe_divide_for_zomato(1200, 4)
print()
safe_divide_for_zomato(1200, 0)
# Out:
# Each person should pay: ₹300.00
# Split calculation done
#
# Error: Number of people cannot be zero.
# Split calculation done
