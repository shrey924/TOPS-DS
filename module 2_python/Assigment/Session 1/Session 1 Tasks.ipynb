# %%
# 1 Done

# %%
# 2 
print("shreyansh")
# Out:
# shreyansh

# %%
print('google')
# Out:
# google

# %%
# 3
print("Welcome to Data Analytics with Python!")
# Out:
# Welcome to Data Analytics with Python!

# %%
# 4
import datetime
print(datetime.datetime.now().year)
print(datetime.datetime.now())
# Out:
# 2026
# 2026-06-27 19:26:20.575821
