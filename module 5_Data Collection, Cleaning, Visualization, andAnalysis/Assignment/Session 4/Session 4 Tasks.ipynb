# %%
# 1 Download a sample CSV file of IPL cricket match scores from Kaggle or any public dataset, and use pd.read_csv() to load it into a DataFrame. Print the first 5 rows to verify the data.

import pandas as pd

df = pd.read_csv("IPL_2026_Data.csv",encoding="latin1")
df.head()
# Out:
#    Match_No           Date        Day      Time                      Venue  \
# 0         1  March 28,2026   Saturday  7:30 P.M     M. Chinnaswamy Stadium
# 1         2  March 29,2026     Sunday  7:30 P.M           Wankhede Stadium
# 2         3  March 30,2026     Monday  7:30 P.M  Barsapara Cricket Stadium
# 3         4  March 31,2026    Tuesday  7:30 P.M    PCA New cricket Stadium
# 4         5   April 1,2026  Wednesday  7:30 P.M      Ekana Cricket Stadium
#
#      Venue_state      Venue_city                        Team1  \
# 0       Karnatka       Bengaluru  Royal Challengers Bangalore
# 1    Maharashtra          Mumbai               Mumbai Indians
# 2          Assam        Guwahati             Rajasthan Royals
# 3         Punjab  New Chandigarh                 Punjab Kings
# 4  Uttar Pradesh         Lucknow         Lucknow Super Giants
#
#   Team1_impact_player                  Team2  ... Second_ings_wickets  \
# 0    Devdutt Padikkal    Sunrisers Hyderabad  ...                   4
# 1    Suryakumar Yadav  Kolkata Knight Riders  ...                   4
# 2           No Result    Chennai Super Kings  ...                   2
# 3       Priyansh Arya         Gujarat Titans  ...                   7
# 4       Shahbaz Ahmed         Delhi Capitals  ...                   4
#
#                   Match_winner   Won_by Margin Player_of_the_match  \
# 0  Royal Challengers Bangalore  wickets      6         Jacob Duffy
# 1               Mumbai Indians  wickets      6      Shardul Thakur
# 2             Rajasthan Royals  wickets      8       Nandre Burger
# 3                 Punjab Kings  wickets      3     Cooper Connolly
# 4               Delhi Capitals  wickets      6        Sameer Rizvi
#
#               top_scorer Batsman_highscore       Best_bowling  \
# 0           Ishan Kishan                80        Jacob Duffy
# 1        Ryan Rickelton                 81     Shardul Thakur
# 2   Vaibhav Sooryavanshi                52       Jofra Archer
# 3        Cooper Connolly                72  Vijaykumar Vyshak
# 4           Sameer Rizvi                70         T Natrajan
#
#   Best_bowling_figure Match_first_over
# 0                3-22      Jacob Duffy
# 1                3-39      Trent Boult
# 2                2-19    Nandre Burger
# 3                3-34   Arshdeep Singh
# 4                3-29     Mukesh Kumar
#
# [5 rows x 27 columns]

# %%
# 2 Done

# %%
# 3 You have a TSV (tab-separated values) file containing Zomato restaurant data. Use pd.read_csv() with the correct separator to load the data, and then use df.describe(include='all') to generate summary statistics.<br><br><em><strong>Hint:</strong> The separator for TSV files is '\t'.</em>
df = pd.read_csv("Zomato-data-.csv", sep="\t")

# Display the first 5 rows
print("First 5 Rows:")
print(df.head())

# Generate summary statistics
print("\nSummary Statistics:")
print(df.describe(include='all'))
# Out:
# First 5 Rows:
#   name,online_order,book_table,rate,votes,approx_cost(for two people),listed_in(type)
# 0                 Jalsa,Yes,Yes,4.1/5,775,800,Buffet
# 1         Spice Elephant,Yes,No,4.1/5,787,800,Buffet
# 2        San Churro Cafe,Yes,No,3.8/5,918,800,Buffet
# 3    Addhuri Udupi Bhojana,No,No,3.7/5,88,300,Buffet
# 4           Grand Village,No,No,3.8/5,166,600,Buffet
#
# Summary Statistics:
#        name,online_order,book_table,rate,votes,approx_cost(for two people),listed_in(type)
# count                                                 148
# unique                                                148
# top                    Jalsa,Yes,Yes,4.1/5,775,800,Buffet
# freq                                                    1

# %%
# 4 
import pandas as pd



# Display data
print("Data:")
print(df)

# Check for missing values
null_counts = df.isnull().sum()

# Print columns with null values
print("\nColumns with missing values:")

for column, count in null_counts.items():
    if count > 0:
        print(f"{column}: {count} missing value(s)")
# Out:
# Data:
#     name,online_order,book_table,rate,votes,approx_cost(for two people),listed_in(type)
# 0                   Jalsa,Yes,Yes,4.1/5,775,800,Buffet
# 1           Spice Elephant,Yes,No,4.1/5,787,800,Buffet
# 2          San Churro Cafe,Yes,No,3.8/5,918,800,Buffet
# 3      Addhuri Udupi Bhojana,No,No,3.7/5,88,300,Buffet
# 4             Grand Village,No,No,3.8/5,166,600,Buffet
# ..                                                 ...
# 143          Melting Melodies,No,No,3.3/5,0,100,Dining
# 144           New Indraprasta,No,No,3.3/5,0,150,Dining
# 145           Anna Kuteera,Yes,No,4.0/5,771,450,Dining
# 146                   Darbar,No,No,3.0/5,98,800,Dining
# 147           Vijayalakshmi,Yes,No,3.9/5,47,200,Dining
#
# [148 rows x 1 columns]
#
# Columns with missing values:
