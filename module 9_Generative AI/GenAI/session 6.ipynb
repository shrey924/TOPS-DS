# %% [markdown]
# | Aspect     | Traditional AI                         | Generative AI (GenAI)                |
# | ---------- | -------------------------------------- | ------------------------------------ |
# | Purpose    | Analyze, classify, or predict data     | Generate new content                 |
# | Output     | Fixed results (labels, predictions)    | New text, images, audio, or code     |
# | Creativity | Limited to predefined tasks            | Can create original content          |
# | Data Usage | Learns patterns for decision-making    | Learns patterns to generate new data |
# | Example    | Spam detection, recommendation systems | ChatGPT, DALL-E, Midjourney          |

# %% [markdown]
# 3. List 5 popular apps or features you use daily (like Instagram Reels, Spotify recommendations, Zomato chatbots, YouTube video summaries, or Flipkart product images) and identify which ones likely use GenAI. For each, briefly explain how GenAI might be working behind the scenes.

# %% [markdown]
# | App/Feature              | Uses GenAI? | How GenAI Might Work                                             |
# | ------------------------ | ----------- | ---------------------------------------------------------------- |
# | Instagram Reels Captions | Yes         | Generates automatic captions, hashtags, and content suggestions. |
# | Spotify AI Playlist      | Yes         | Creates personalized playlists and playlist descriptions.        |
# | Zomato Chat Support      | Yes         | Generates natural language responses to customer queries.        |
# | YouTube Video Summaries  | Yes         | Creates concise summaries of long videos.                        |
# | Flipkart Product Images  | Yes         | Generates or enhances product images and descriptions.           |

# %% [markdown]
# 4. Use ChatGPT or any GenAI tool to generate a short poem (4-6 lines) about your favorite food app (Zomato, Swiggy, etc.), then paste the output and describe in 2-3 lines how the tool created something new rather than just retrieving existing text.

# %% [markdown]
# Prompt Used:
#
# Write a short 4–6 line poem about Zomato.
#
# Output:
#
# Zomato brings food to my door,
# From tasty snacks to so much more.
# With just a click, my meal is near,
# Hot and fresh, it brings good cheer.
# Day or night, it's ready to go,
# Making hunger disappear in a glow.
