# %% [markdown]
# 1.List 3 apps you use daily (like Instagram, Zomato, Spotify) and describe one feature in each that could be powered by a generative AI model instead of traditional rule-based logic.

# %% [markdown]
# | App       | Current Feature               | Generative AI-Powered Feature                                                              |
# | --------- | ----------------------------- | ------------------------------------------------------------------------------------------ |
# | Instagram | Content recommendations       | AI-generated personalized captions and hashtags for posts.                                 |
# | Zomato    | Restaurant search and reviews | AI-generated restaurant summaries based on reviews and user preferences.                   |
# | Spotify   | Music recommendations         | AI-generated personalized playlists with descriptions based on mood and listening history. |

# %% [markdown]
# 2.Create a table comparing discriminative models and generative models across at least 4 aspects (definition, main use, example task, example model name).

# %% [markdown]
# | Aspect        | Discriminative Models                                  | Generative Models                                          |
# | ------------- | ------------------------------------------------------ | ---------------------------------------------------------- |
# | Definition    | Learn the boundary between classes and predict labels. | Learn the data distribution and generate new data samples. |
# | Main Use      | Classification and prediction.                         | Content generation and data creation.                      |
# | Example Task  | Spam email detection.                                  | Generating text, images, or music.                         |
# | Example Model | Logistic Regression, SVM, ResNet.                      | GPT, GAN, VAE.                                             |

# %% [markdown]
# 3.Use ChatGPT to generate a short product description for a new Flipkart gadget (make up the gadget). Copy the prompt you used and the output you received.<br><br><em><strong>

# %% [markdown]
# Prompt Used:
#
# Write a product description for a new Flipkart gadget called "SmartBand X1". It is a fitness band with heart-rate monitoring, sleep tracking, 10-day battery life, water resistance, and AI-powered health insights. Keep the description attractive and under 100 words.
#
# Output Received:
#
# SmartBand X1 – Your Smart Fitness Companion
# Stay ahead of your fitness goals with the SmartBand X1. Track your heart rate, monitor sleep quality, and receive AI-powered health insights tailored to your lifestyle. With a long-lasting 10-day battery and water-resistant design, it's perfect for workouts and everyday use. Lightweight, stylish, and packed with smart features, SmartBand X1 helps you stay healthy and connected wherever you go.

# %% [markdown]
# 4.Pick one generative AI application (text generation, image synthesis, music/audio generation, or code generation) and describe a new feature you would add to an app you use, explaining how generative AI would power it.

# %% [markdown]
# Application Chosen: Text Generation
#
# App: Zomato
#
# New Feature: AI Meal Planner
#
# Description:
# A generative AI-powered meal planner could create personalized meal recommendations based on a user's dietary preferences, budget, health goals, and previous orders. For example, if a user wants a high-protein vegetarian meal under ₹300, the AI can generate a customized list of dishes and restaurants available nearby. This would provide a more personalized and engaging food-ordering experience than traditional recommendation systems.
