# %%
import cv2
import glob

# %%
img = cv2.imread(r"S:\CV Assessment\Data\home.jpg")
print(f"Original size: {img.shape}")


cv2.imshow("My First Image", img)
cv2.waitKey(0)      
cv2.destroyAllWindows()
# Out:
# Original size: (384, 512, 3)

# %%
# Convert BGR to Grayscale
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
print(f"Grayscale shape: {gray.shape}")
cv2.imshow("grayscale image", gray)
cv2.waitKey(0)      
cv2.destroyAllWindows()
# Out:
# Grayscale shape: (384, 512)

# %%
# resize image  
gray_resize = cv2.resize(gray, (512, 512),interpolation=cv2.INTER_CUBIC)

# %%
# MEDIAN BLUR 
median = cv2.medianBlur(gray_resize, 5)
cv2.imshow("gray", gray_resize)
cv2.imshow("Median Blur",   median)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
# CANNY EDGE DETECTION

gray_blur = cv2.GaussianBlur(median, (5, 5), 0)

edges = cv2.Canny(gray_blur, 50, 100)
cv2.imshow("Original",median)
cv2.imshow("Edges (Canny)", edges)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
cv2.imshow("Original",      img)
cv2.imshow("grayscale image", gray)
cv2.imshow("resize", gray_resize)
cv2.imshow("Median Blur",   median)
cv2.imshow("Edges (Canny)", edges)
cv2.waitKey(0)
cv2.destroyAllWindows()
