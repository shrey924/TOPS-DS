# %% [markdown]
# Tasks 1:
# Done .

# %% [markdown]
#  Tasks 2
#  Biological Neuron                    Artificial Neuron
#
#   Dendrites                            Inputs (x1,x2,x3)
#       \   |   /                            \  |  /
#        \  |  /                           Weights
#         \ | /                           (w1,w2,w3)
#       [ Soma ]                            [ Σ ]
#    (Processing)                      (Weighted Sum)
#           |                                 |
#           |                                 |
#        [Axon]                    [Activation Function]
#        Output                              |
#                                             |
#                                         Output (y)

# %% [markdown]
# Tasks 3
#
# App : Instagram
# Feature Using  : Feed Recommendations
# How Deep Learning Helps : Deep learning analyzes your likes, comments, shares, watch time, and follows to predict which posts and reels you are most likely to engage with. This makes the feed more personalized.
#
# App : Spotify
# Feature Using : Music Recommendations
# How Deep Learning Helps : Deep learning learns patterns in your listening history and compares them with millions of other users to recommend songs, artists, and playlists you may enjoy.
#
# App : Zomato
# Feature Using : Restaurant and Food Recommendations
# How Deep Learning Helps : Deep learning can analyze previous orders, ratings, search history, location, and time of day to suggest restaurants and dishes that match your preferences.

# %% [markdown]
# Tasks : 4
#
# 1. Collect User Data
# 2. Store and Organize Data
# 3. Data Preprocessing
# 4. Feature Engineering
# 5. Split the Dataset
# 6. Build the Deep Learning Model
# 7. Compile the Model
# 8. Train the Model
# 9. Evaluate Performance
# 10. Generate Recommendations
# 11. Save the Trained Model
